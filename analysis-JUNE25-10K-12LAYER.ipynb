# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Model + Data Loading

# %%
import pprint

import pandas as pd
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from pathlib import Path

from language_structure import *
from train import load, load_dataloader
from model import *
from utils import *
from bert import tokenization

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vocab_file = './uncased_L-12_H-768_A-12/vocab.txt'
tokenizer = tokenization.FullTokenizer(vocab_file=vocab_file, do_lower_case=True)
pp = pprint.PrettyPrinter(indent=4)
ID = "JUNE25-10K-12LAYER"

# %% [markdown]
# # IMDB

# %%
model_path = 'complete_IMDB-VD-{}'.format(ID)
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5bf85077c215> in <module>
#       1 model_path = 'complete_IMDB-VD-{}'.format(ID)
# ----> 2 model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
#       3 m1['args']['--save-to'] = 'Vanilla Dropout'
#       4 plot_metrics(m1, first_n=None)
#       5 pp.pprint(m1['args'])
#
# ~/Documents/nlp_project/Dropout-Attention/train.py in load(path, cpu, load_model)
#      76 def load(path, cpu=False, load_model=True):
#      77     model_dir = 'model_saves/' + path
# ---> 78     metrics = torch.load(model_dir + '/metrics.pt')
#      79     # lang = model_checkpoint['vocab']
#      80
#
# ~/anaconda2/envs/nlp/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     380             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     381         new_fd = True
# --> 382         f = open(f, 'rb')
#     383     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     384         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_saves/complete_IMDB-VD-JUNE25-10K-12LAYER/metrics.pt'

# %%
model_path = 'complete_IMDB-AD-{}'.format(ID)
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ed9c006bbb61> in <module>
#       1 model_path = 'complete_IMDB-AD-{}'.format(ID)
# ----> 2 model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
#       3 m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
#       4 plot_metrics(m2, first_n=None)
#       5 pp.pprint(m2['args'])
#
# ~/Documents/nlp_project/Dropout-Attention/train.py in load(path, cpu, load_model)
#      76 def load(path, cpu=False, load_model=True):
#      77     model_dir = 'model_saves/' + path
# ---> 78     metrics = torch.load(model_dir + '/metrics.pt')
#      79     # lang = model_checkpoint['vocab']
#      80
#
# ~/anaconda2/envs/nlp/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     380             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     381         new_fd = True
# --> 382         f = open(f, 'rb')
#     383     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     384         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_saves/complete_IMDB-AD-JUNE25-10K-12LAYER/metrics.pt'

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-48fe8abd7638> in <module>
# ----> 1 compare_metrics([m1, m2], first_n=None)
#
# NameError: name 'm1' is not defined

# %% [markdown]
# # COLA

# %%
model_path = 'complete_COLA-VD-{}'.format(ID)
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# Total Time: 203.7833
# Train Time: 163.3426
# Max (Validation, Train): (0.65, 0.78)
# {   '--COLA': True,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': False,
#     '--batch-size': '32',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.1',
#     '--dset-size': '10000',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '2',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Vanilla Dropout',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '10'}

# %%
model_path = 'complete_COLA-AD-{}'.format(ID)
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# Total Time: 257.7721
# Train Time: 216.0074
# Max (Validation, Train): (0.65, 0.77)
# {   '--COLA': True,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': True,
#     '--batch-size': '32',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.1',
#     '--dset-size': '10000',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '2',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Attention-Dropout (Ours)',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '10'}

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# --------Vanilla Dropout----------
# Max (Validation, Train): (0.65, 0.78)
# Total Time: 203.7833
# Train Time: 163.3426
# --------Attention-Dropout (Ours)----------
# Max (Validation, Train): (0.65, 0.77)
# Total Time: 257.7721
# Train Time: 216.0074

# %% [markdown]
# # QNLI

# %%
model_path = 'complete_QNLI-VD-{}'.format(ID)
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# Total Time: 442.8739
# Train Time: 209.6966
# Max (Validation, Train): (0.57, 0.57)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': True,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': False,
#     '--batch-size': '32',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.1',
#     '--dset-size': '10000',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '2',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Vanilla Dropout',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '10'}

# %%
model_path = 'complete_QNLI-AD-{}'.format(ID)
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# Total Time: 490.6072
# Train Time: 266.9911
# Max (Validation, Train): (0.54, 0.56)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': True,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': True,
#     '--batch-size': '32',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.1',
#     '--dset-size': '10000',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '2',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Attention-Dropout (Ours)',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '10'}

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# --------Vanilla Dropout----------
# Max (Validation, Train): (0.57, 0.57)
# Total Time: 442.8739
# Train Time: 209.6966
# --------Attention-Dropout (Ours)----------
# Max (Validation, Train): (0.54, 0.56)
# Total Time: 490.6072
# Train Time: 266.9911

# %% [markdown]
# # QQP

# %%
# model_path = 'complete_QQP-VD-{}'.format(ID)
model_path = 'cancel_e=0_itr=225QQP-VD-JUNE25-10K-6LAYER'
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# Total Time: 95.1456
# Train Time: 37.3551
# Max (Validation, Train): (0.68, 0.64)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': True,
#     '--RTE': False,
#     '--attention-dropout': False,
#     '--batch-size': '32',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.1',
#     '--dset-size': '10000',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '3',
#     '--max-sent-len': '512',
#     '--n-heads': '6',
#     '--n-layers': '6',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Vanilla Dropout',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '10'}

# %%
model_path = 'complete_QQP-AD-{}'.format(ID)
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-6cec5efce628> in <module>
#       1 model_path = 'complete_QQP-AD-{}'.format(ID)
# ----> 2 model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
#       3 m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
#       4 plot_metrics(m2, first_n=None)
#       5 pp.pprint(m2['args'])
#
# ~/Documents/nlp_project/Dropout-Attention/train.py in load(path, cpu, load_model)
#      78     # lang = model_checkpoint['vocab']
#      79     if cpu:
# ---> 80         metrics = torch.load(model_dir + '/metrics.pt', map_location='cpu')
#      81     else:
#      82         metrics = torch.load(model_dir + '/metrics.pt')
#
# ~/anaconda2/envs/nlp/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     380             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     381         new_fd = True
# --> 382         f = open(f, 'rb')
#     383     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     384         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model_saves/complete_QQP-AD-JUNE25-10K-12LAYER/metrics.pt'

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# --------Vanilla Dropout----------
# Max (Validation, Train): (0.68, 0.64)
# Total Time: 95.1456
# Train Time: 37.3551
# --------Attention-Dropout (Ours)----------
# Max (Validation, Train): (0.77, 0.85)
# Total Time: 447.708
# Train Time: 208.4126

# %% [markdown]
# # RTE

# %%
model_path = 'complete_RTE-VD-{}'.format(ID)
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# Total Time: 104.801
# Train Time: 65.1199
# Max (Validation, Train): (0.22, 0.56)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': False,
#     '--RTE': True,
#     '--attention-dropout': False,
#     '--batch-size': '32',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.1',
#     '--dset-size': '0',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '2',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Vanilla Dropout',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '10'}

# %%
model_path = 'complete_RTE-AD-{}'.format(ID)
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# Total Time: 125.5785
# Train Time: 83.934
# Max (Validation, Train): (0.20, 0.53)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': False,
#     '--RTE': True,
#     '--attention-dropout': True,
#     '--batch-size': '32',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.1',
#     '--dset-size': '0',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '2',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Attention-Dropout (Ours)',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '10'}

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# --------Vanilla Dropout----------
# Max (Validation, Train): (0.22, 0.56)
# Total Time: 104.801
# Train Time: 65.1199
# --------Attention-Dropout (Ours)----------
# Max (Validation, Train): (0.20, 0.53)
# Total Time: 125.5785
# Train Time: 83.934
