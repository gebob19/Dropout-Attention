# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Model + Data Loading

# %%
import pprint

import pandas as pd
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from pathlib import Path

from language_structure import *
from train import load, load_dataloader
from model import *
from utils import *
from bert import tokenization

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vocab_file = './uncased_L-12_H-768_A-12/vocab.txt'
tokenizer = tokenization.FullTokenizer(vocab_file=vocab_file, do_lower_case=True)
pp = pprint.PrettyPrinter(indent=4)
ID = "JUNE26-UPDATED2-6-12-LAYER"

# %% [markdown]
# # IMDB

# %%
model_path = 'complete_IMDB-VD-{}'.format(ID)
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# Total Time: 2331.8243
# Train Time: 941.269
# Max (Validation, Train): (0.54, 0.64)
# {   '--COLA': False,
#     '--IMDB': True,
#     '--QNLI': False,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': False,
#     '--batch-size': '8',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.3',
#     '--dset-size': '0',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '1',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '2000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Vanilla Dropout',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '50'}

# %%
model_path = 'complete_IMDB-AD-{}'.format(ID)
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# Total Time: 2571.856
# Train Time: 1202.3809
# Max (Validation, Train): (0.89, 0.97)
# {   '--COLA': False,
#     '--IMDB': True,
#     '--QNLI': False,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': True,
#     '--batch-size': '8',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.3',
#     '--dset-size': '0',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '1',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '2000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Attention-Dropout (Ours)',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '50'}

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# --------Vanilla Dropout----------
# Max (Validation, Train): (0.54, 0.64)
# Total Time: 2331.8243
# Train Time: 941.269
# --------Attention-Dropout (Ours)----------
# Max (Validation, Train): (0.89, 0.97)
# Total Time: 2571.856
# Train Time: 1202.3809

# %% [markdown]
# # COLA

# %%
model_path = 'complete_COLA-VD-{}'.format(ID)
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# Total Time: 514.9421
# Train Time: 405.2629
# Max (Validation, Train): (0.70, 0.75)
# {   '--COLA': True,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': False,
#     '--batch-size': '16',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.5',
#     '--dset-size': '0',
#     '--help': False,
#     '--hidden-size': '768',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '20',
#     '--lr': '3e-5',
#     '--max-epoch': '5',
#     '--max-sent-len': '512',
#     '--n-heads': '6',
#     '--n-layers': '6',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Vanilla Dropout',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '50'}

# %%
model_path = 'complete_COLA-AD-{}'.format(ID)
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# Total Time: 617.3793
# Train Time: 514.5426
# Max (Validation, Train): (0.70, 0.76)
# {   '--COLA': True,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': True,
#     '--batch-size': '16',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.5',
#     '--dset-size': '0',
#     '--help': False,
#     '--hidden-size': '768',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '20',
#     '--lr': '3e-5',
#     '--max-epoch': '5',
#     '--max-sent-len': '512',
#     '--n-heads': '6',
#     '--n-layers': '6',
#     '--n-valid': '1000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Attention-Dropout (Ours)',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '50'}

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# --------Vanilla Dropout----------
# Max (Validation, Train): (0.70, 0.75)
# Total Time: 514.9421
# Train Time: 405.2629
# --------Attention-Dropout (Ours)----------
# Max (Validation, Train): (0.70, 0.76)
# Total Time: 617.3793
# Train Time: 514.5426

# %% [markdown]
# # QNLI

# %%
model_path = 'complete_QNLI-VD-{}'.format(ID)
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# Total Time: 2408.4243
# Train Time: 1073.9222
# Max (Validation, Train): (0.51, 0.64)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': True,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': False,
#     '--batch-size': '16',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.5',
#     '--dset-size': '50000',
#     '--help': False,
#     '--hidden-size': '768',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '2',
#     '--max-sent-len': '512',
#     '--n-heads': '6',
#     '--n-layers': '6',
#     '--n-valid': '5000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Vanilla Dropout',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '100'}

# %%
# model_path = 'complete_QNLI-AD-{}'.format(ID)
model_path = 'cancel_e=0_itr=2631QNLI-AD-JUNE26-UPDATED2-6-12-LAYER'
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# Total Time: 1132.4686
# Train Time: 611.2257
# Max (Validation, Train): (0.57, 0.63)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': True,
#     '--QQP': False,
#     '--RTE': False,
#     '--attention-dropout': True,
#     '--batch-size': '16',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.5',
#     '--dset-size': '50000',
#     '--help': False,
#     '--hidden-size': '192',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '2',
#     '--max-sent-len': '512',
#     '--n-heads': '6',
#     '--n-layers': '6',
#     '--n-valid': '5000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Attention-Dropout (Ours)',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '100'}

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# --------Vanilla Dropout----------
# Max (Validation, Train): (0.51, 0.64)
# Total Time: 2408.4243
# Train Time: 1073.9222
# --------Attention-Dropout (Ours)----------
# Max (Validation, Train): (0.57, 0.63)
# Total Time: 1132.4686
# Train Time: 611.2257

# %% [markdown]
# # QQP

# %%
model_path = 'complete_QQP-VD-{}'.format(ID)
model1, _, _, m1 = load(model_path, cpu=True, load_model=False)
m1['args']['--save-to'] = 'Vanilla Dropout'
plot_metrics(m1, first_n=None)
pp.pprint(m1['args'])
# Out:
# Total Time: 618.7913
# Train Time: 364.6111
# Max (Validation, Train): (0.79, 0.88)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': True,
#     '--RTE': False,
#     '--attention-dropout': False,
#     '--batch-size': '16',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.3',
#     '--dset-size': '20000',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '1',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '2000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Vanilla Dropout',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '50'}

# %%
model_path = 'complete_QQP-AD-{}'.format(ID)
model2, _, _, m2 = load(model_path, cpu=True, load_model=False)
m2['args']['--save-to'] = 'Attention-Dropout (Ours)'
plot_metrics(m2, first_n=None)
pp.pprint(m2['args'])
# Out:
# Total Time: 727.048
# Train Time: 469.1677
# Max (Validation, Train): (0.78, 0.90)
# {   '--COLA': False,
#     '--IMDB': False,
#     '--QNLI': False,
#     '--QQP': True,
#     '--RTE': False,
#     '--attention-dropout': True,
#     '--batch-size': '16',
#     '--clip-grad': '5.0',
#     '--decrease-dropout': '10',
#     '--dropout': '0.3',
#     '--dset-size': '20000',
#     '--help': False,
#     '--hidden-size': '384',
#     '--load': False,
#     '--load-from': 'default-model',
#     '--log-every': '10',
#     '--lr': '3e-5',
#     '--max-epoch': '1',
#     '--max-sent-len': '512',
#     '--n-heads': '12',
#     '--n-layers': '12',
#     '--n-valid': '2000',
#     '--n-words': '10000',
#     '--qtest': False,
#     '--save': True,
#     '--save-to': 'Attention-Dropout (Ours)',
#     '--seed': '0',
#     '--start-decrease': '100',
#     '--test': False,
#     '--validate-every': '50'}

# %%
compare_metrics([m1, m2], first_n=None)
# Out:
# --------Vanilla Dropout----------
# Max (Validation, Train): (0.79, 0.88)
# Total Time: 618.7913
# Train Time: 364.6111
# --------Attention-Dropout (Ours)----------
# Max (Validation, Train): (0.78, 0.90)
# Total Time: 727.048
# Train Time: 469.1677
